# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd
import contractions

from nltk.tokenize import word_tokenize

# %%
path = r"../data/raw/training.1600000.processed.noemoticon.csv"

data = pd.read_csv(path, encoding="latin1")

df = pd.DataFrame(data)

df.columns = ["Label", "Serial", "Date", "Query", "Twitter_id", "Tweet"]

# %%
df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
df["Clean_Text"] = df["Tweet"]

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %% [markdown]
# ### lowercase

# %%
df["Clean_Text"] = df["Tweet"].fillna("").astype(str).str.lower()

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text
# 0  is upset that he can't update his facebook by ...
# 1  @kenichan i dived many times for the ball. man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @kwesidei not the whole crew

# %% [markdown]
# ### URL removal

# %%
pattern = r"https?://\S+"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### mention removal

# %%
pattern = r"@\w+"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### hashtag cleaning

# %%
pattern = r"#"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### Punctuation removal

# %%
pattern = r"[!?_]"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### Space cleaning

# %%
df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    apply(lambda x: " ".join(x.split())))

# %% [markdown]
# ### contractions

# %%
df["Clean_Text"] = df["Clean_Text"].fillna("").astype(str).apply(
    lambda x: (contractions.fix(x))
)

# %% [markdown]
# ### Tokenization

# %%
df["Tokens"] = df["Clean_Text"].fillna("").astype(str).apply(word_tokenize)

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text  \
# 0  is upset that he cannot update his facebook by...
# 1  i dived many times for the ball. managed to sa...
# 2     my whole body feels itchy and like its on fire
# 3  no, it is not behaving at all. i am mad. why a...
# 4                                 not the whole crew
#
#                                               Tokens
# 0  [is, upset, that, he, can, not, update, his, f...
# 1  [i, dived, many, times, for, the, ball, ., man...
# 2  [my, whole, body, feels, itchy, and, like, its...
# 3  [no, ,, it, is, not, behaving, at, all, ., i, ...
# 4                            [not, the, whole, crew]

# %% [markdown]
# ### Stopwords cleaning

# %%
stop_words = set(["is", "the", "if", "that", "at", "of", "a", "an", "it",
                  "to", "in", "on", "for", "with", "and", "or", "but"])

df["Tokens"] = df["Tokens"].apply(
    lambda x: [word for word in x if word not in stop_words]
)

# %%
df["Tokens"]
# Out:
# 0          [upset, he, can, not, update, his, facebook, b...
# 1          [i, dived, many, times, ball, ., managed, save...
# 2           [my, whole, body, feels, itchy, like, its, fire]
# 3          [no, ,, not, behaving, all, ., i, am, mad, ., ...
# 4                                         [not, whole, crew]
#                                  ...
# 1599994    [just, woke, up, ., having, no, school, best, ...
# 1599995    [thewdb.com, -, very, cool, hear, old, walt, i...
# 1599996    [are, you, ready, your, mojo, makeover, ask, m...
# 1599997    [happy, 38th, birthday, my, boo, alll, time, t...
# 1599998                              [happy, charitytuesday]
# Name: Tokens, Length: 1599999, dtype: object

# %% [markdown]
# ### Final Conclution

# %%
df[["Tweet", "Clean_Text"]].sample(10)
# Out:
#                                                      Tweet  \
# 1309366  @DanielaL Sounds exciting! On scooter it felt ...
# 527432   @realtin its not mine  im looking for somethin...
# 1351119                      @brooklynblondie thank you!!
# 687695   The problem with using a mac and an avi video ...
# 269099   problem: need to keep studying, but brain is f...
# 445834   have installed Adobe Photoshop Album Starter E...
# 348508                                Why is it raining!?
# 585545   can't stand these ups &amp; downs... I actuall...
# 165108   Been 2 years and m still devistated that they ...
# 505975   i'm sick..fault of sudden change of weather..s...
#
#                                                 Clean_Text
# 1309366  sounds exciting on scooter it felt like being ...
# 527432   its not mine i am looking for something like t...
# 1351119                                          thank you
# 687695   the problem with using a mac and an avi video ...
# 269099   problem: need to keep studying, but brain is f...
# 445834   have installed adobe photoshop album starter e...
# 348508                                   why is it raining
# 585545   cannot stand these ups &amp; downs... i actual...
# 165108   been 2 years and m still devistated that they ...
# 505975   i am sick..fault of sudden change of weather.....

# %%
df.drop(["Tweet", "Query"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Label      Serial                          Date     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009       joy_wolf
#
#                                           Clean_Text  \
# 0  is upset that he cannot update his facebook by...
# 1  i dived many times for the ball. managed to sa...
# 2     my whole body feels itchy and like its on fire
# 3  no, it is not behaving at all. i am mad. why a...
# 4                                 not the whole crew
#
#                                               Tokens
# 0  [upset, he, can, not, update, his, facebook, b...
# 1  [i, dived, many, times, ball, ., managed, save...
# 2   [my, whole, body, feels, itchy, like, its, fire]
# 3  [no, ,, not, behaving, all, ., i, am, mad, ., ...
# 4                                 [not, whole, crew]

# %%
df.to_csv("../data/processed/cleaned_sentiment140.csv", index=False)
