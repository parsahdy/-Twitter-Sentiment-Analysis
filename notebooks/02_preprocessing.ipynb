# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd
import contractions
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
path = r"../data/raw/training.1600000.processed.noemoticon.csv"

data = pd.read_csv(path, encoding="latin1")

df = pd.DataFrame(data)

df.columns = ["Label", "Serial", "Date", "Query", "Twitter_id", "Tweet"]

# %%
df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
df["Clean_Text"] = df["Tweet"]

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %% [markdown]
# ### lowercase

# %%
df["Clean_Text"] = df["Tweet"].fillna("").astype(str).str.lower()

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text
# 0  is upset that he can't update his facebook by ...
# 1  @kenichan i dived many times for the ball. man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @kwesidei not the whole crew

# %% [markdown]
# Label

# %%
df.loc[df["Label"] == 4, "Label"] = 1

# %%
df.tail()
# Out:
#          Label      Serial                          Date     Query  \
# 1599994      1  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995      1  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996      1  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997      1  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998      1  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#               Twitter_id                                              Tweet  \
# 1599994  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599995      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599996           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599997     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
#                                                 Clean_Text
# 1599994  just woke up. having no school is the best fee...
# 1599995  thewdb.com - very cool to hear old walt interv...
# 1599996  are you ready for your mojo makeover? ask me f...
# 1599997  happy 38th birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @thenspcc @sparkscharity...

# %% [markdown]
# ### URL removal

# %%
pattern = r"https?://\S+"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### mention removal

# %%
pattern = r"@\w+"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### hashtag cleaning

# %%
pattern = r"#"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### Punctuation removal

# %%
pattern = r"[!?_]"

df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    str.replace(pattern, "", regex=True))

# %% [markdown]
# ### Space cleaning

# %%
df["Clean_Text"] = (df["Clean_Text"].fillna("").astype(str).
                    apply(lambda x: " ".join(x.split())))

# %% [markdown]
# ### contractions

# %%
df["Clean_Text"] = df["Clean_Text"].fillna("").astype(str).apply(
    lambda x: (contractions.fix(x))
)

# %% [markdown]
# ### Tokenization

# %%
df["Tokens"] = df["Clean_Text"].fillna("").astype(str).apply(word_tokenize)

df.head()
# Out:
#    Label      Serial                          Date     Query     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                Tweet  \
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
#
#                                           Clean_Text  \
# 0  is upset that he cannot update his facebook by...
# 1  i dived many times for the ball. managed to sa...
# 2     my whole body feels itchy and like its on fire
# 3  no, it is not behaving at all. i am mad. why a...
# 4                                 not the whole crew
#
#                                               Tokens
# 0  [is, upset, that, he, can, not, update, his, f...
# 1  [i, dived, many, times, for, the, ball, ., man...
# 2  [my, whole, body, feels, itchy, and, like, its...
# 3  [no, ,, it, is, not, behaving, at, all, ., i, ...
# 4                            [not, the, whole, crew]

# %% [markdown]
# ### Stopwords cleaning

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Parsa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words("english"))

stop_words.discard("not")

df["Tokens"] = df["Tokens"].apply(
    lambda x: [word for word in x if word.lower() not in stop_words]
)

df["Clean_Text"] = df["Tokens"].apply(lambda x: " ".join(x))

# %%
df["Tokens"].sample(5)
# Out:
# 944004     [someone, told, &, quot, ;, 7things, climb, &,...
# 1196356            [yum, jealous, &, amp, ;, craving, sushi]
# 784768     [tired, ,, hungry, like, half, seven, ,, cba, ...
# 648132     [synced, tvshows, istore, touch, not, find, .,...
# 1361783    [sicid, rite, .., wrote, back, ..., neva, tlk,...
# Name: Tokens, dtype: object

# %%
df["Clean_Text"].sample(5)
# Out:
# 1293646    back school .. loves project week ... totally ...
# 1347214       home work , deciding tonight . going eat first
# 39287                 hate whenever rains heavily home alone
# 634206     lil bro got clean break left forearm skating y...
# 193230     sunniest saturday far working day saturdays ba...
# Name: Clean_Text, dtype: str

# %% [markdown]
# ### Final Conclution

# %%
df[["Tweet", "Clean_Text"]].sample(10)
# Out:
#                                                      Tweet  \
# 574722             In the batcave Grad School sucks....  !
# 1377341  I'm home studying on a Friday night for my fin...
# 816259        man so board. Im going to play guitar hero.
# 1203443  @schillingfan You're pushing it, Missy. Howeve...
# 1088774  fuk you word limit...to be honest no one likes...
# 696417                     everything's going wrong today
# 807392   should be getting her passport interview done ...
# 124516   this makes me so angry =&gt; http://bit.ly/SgV...
# 369461                          @jima6636 you mad at me ?
# 1539061  @Enjoem Feels a lot better.  I was flushing it...
#
#                                                 Clean_Text
# 574722                      batcave grad school sucks ....
# 1377341  home studying friday night final tomorrow ... ...
# 816259                man board . going play guitar hero .
# 1203443  pushing , missy . however , try dig sparkly sh...
# 1088774                fuk word limit ... honest one likes
# 696417                     everything 's going wrong today
# 807392          getting passport interview done tomorrow .
# 124516   makes angry = & gt ; dumbarse truckie , poor a...
# 369461                                                 mad
# 1539061  feels lot better . flushing regularly keep lub...

# %%
df.drop(["Tweet", "Query"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Label      Serial                          Date     Twitter_id  \
# 0      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  scotthamilton
# 1      0  1467810917  Mon Apr 06 22:19:53 PDT 2009       mattycus
# 2      0  1467811184  Mon Apr 06 22:19:57 PDT 2009        ElleCTF
# 3      0  1467811193  Mon Apr 06 22:19:57 PDT 2009         Karoli
# 4      0  1467811372  Mon Apr 06 22:20:00 PDT 2009       joy_wolf
#
#                                           Clean_Text  \
# 0  upset not update facebook texting ... might cr...
# 1  dived many times ball . managed save 50 % rest...
# 2                   whole body feels itchy like fire
# 3                   , not behaving . mad . not see .
# 4                                     not whole crew
#
#                                               Tokens
# 0  [upset, not, update, facebook, texting, ..., m...
# 1  [dived, many, times, ball, ., managed, save, 5...
# 2            [whole, body, feels, itchy, like, fire]
# 3         [,, not, behaving, ., mad, ., not, see, .]
# 4                                 [not, whole, crew]

# %%
df.to_csv("../data/processed/cleaned_sentiment140.csv", index=False)
